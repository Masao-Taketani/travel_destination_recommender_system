# %%
from gensim.models import word2vec

json_file_path = 'data/test_user.json'

#Wikipediaで学習させたWord2Vecモデルのロード
model = word2vec.Word2Vec.load('data/wiki.model')

# %%
import json
import csv

#JSONファイルを読み込んだ後に、csvファイルを作成
with open(json_file_path) as f:
    json_list = json.load(f)
    json_data = json_list[0]
    
    with open('data/test_data.csv', 'w') as csv_file:
        fieldnames = ['id', 'place_name', 'review_title', 'review_main', 'rank']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
        for i, place_name in enumerate(json_data['news']):
            writer.writerow({'id': i, 'place_name': place_name, 'review_title': json_data['news'][place_name]['news_title'], \
                             'review_main': json_data['news'][place_name]['news_main'], 'rank': json_data['news'][place_name]['rank']})

# %%
def vectorize_words(word):
    model.wv

# %%
import MeCab

#MeCabの初期化(mecab-ipadic-neologdの辞書を使用)
tagger = MeCab.Tagger("-d /var/lib/mecab/dic/mecab-ipadic-neologd")

#分かち書きを行って、必要な単語の原形を取得
def tokenize(text):
    #形態素解析を行う
    result = []
    parsed_words = tagger.parse(text)
    for n in parsed_words.split("\n"):
        if n == 'EOS' or n == '':
            continue
        parse_splited = n.split("\t")[1].split(",")
        hinshi1, hinshi2, original = (parse_splited[0], parse_splited[1], parse_splited[6])
        if not (hinshi1 in ['名詞', '動詞', '形容詞']):
            continue
        if hinshi1 == '名詞' and hinshi2 == '数':
            continue
        result.append(original)
    return result

# %%
import pandas as pd

csv_input = pd.read_csv("data/test_data.csv", sep=",")
csv_input
# Out:
#     id               place_name                    review_title  \
# 0    0                     桂沢湖                        荒れ果てた駐車場！
# 1    1                   三段滝公園               落差は小さいけど、水量豊富で大迫力！
# 2    2               札幌東急REIホテル                  札幌すすきのにある大型ホテル
# 3    3                  狸小路商店街                     今や外国人向けの商店街？
# 4    4                    桂沢ダム             新桂沢ダムが完成すると水没するらしいです
# 5    5                  ラビスタ大雪山             標高１０００ｍ越えに建つ山岳リゾート！
# 6    6             ぜるぶの丘・亜斗夢の丘                   １０月初めはまだまだ花盛り！
# 7    7               支笏湖スカイロード                        森の中を突き進む道
# 8    8              きのこ王国 大滝本店                     となりの道の駅は閉鎖中？
# 9    9                   北海道神宮                北海道一宮にふさわしい雰囲気ですね
# 10  10        札幌みその 札幌ラーメン共和国店                     あぶり豚盛り味噌ラーメン
# 11  11           ビアードパパ 札幌エスタ店               いつもサクサクのパイ生地がいいですね
# 12  12                 真駒内滝野霊園                広大な霊園入り口にモアイ像を発見！
# 13  13             すみれ 札幌すすきの店                    札幌ラーメンの名店、すみれ
# 14  14                  ラーメン櫻島                 これが鹿児島ラーメンなんですね！
# 15  15              上富良野 見晴台公園                      十勝岳がきれいでした！
# 16  16               札幌ラーメン共和国       こちらに入っているラーメン屋さんに外れはありません！
# 17  17             札幌市電 (路面電車)         すすきのと西４丁目がつながってループ化されました
# 18  18                    開拓神社                北海道神宮の境内に建つ末社のひとつ
# 19  19               旭岳ビジターセンター                 新しいビジターセンターに期待！
# 20  20                 旭岳ロープウェイ                １０分で標高１６００ｍの世界へ！
# 21  21                   新桂沢ダム                  今の桂沢ダムのすぐ横に造成中！
# 22  22                    円山公園                     動物園や北海道神宮を歩く
# 23  23                     三段滝   落差は大きくはありませんが間近で見られるので大迫力なんです！
# 24  24                支笏湖翠山亭倶楽部                わずか５部屋の隠れ家オーベルジュ
# 25  25             支笏湖ビジターセンター            支笏湖と樽前山、そして周囲の自然を学べます
# 26  26               ふじ屋NOODLE                   トロッとおいしい味噌ラーメン
# 27  27                    牧歌の像                    ＪＲ札幌駅南口のブロンズ像
# 28  28                   札幌駅前通           札幌駅からすすきのまで札幌の中心街を貫く通り
# 29  29                 札幌市営地下鉄            ゴムの車輪なのでガタッゴトッと言いません！
# 30  30               六花亭 神宮茶屋店                   熱々の「判官さま」をいただく
# 31  31                  札幌市時計台               札幌の発展を見守り続ける歴史的建造物
# 32  32         ジェラテリア エ カフェ ジジ         パンケーキにたっぷりのジェラートとフルーツたち！
# 33  33                恵庭ふるさと公園                  ＪＲ恵庭駅北口から徒歩４～５分
# 34  34                札幌市円山動物園                 残念！空飛ぶシロクマは見られず！
# 35  35   石屋製菓 大丸札幌店 ISHIYAショップ              大丸の地下１階にある白い恋人の石屋製菓
# 36  36          ミア アンジェラ 大丸札幌店                 大丸８階のカジュアル・イタリアン
# 37  37     滝野すずらん丘陵公園 こどもの谷休憩所          広い滝野すずらん丘陵公園の休憩ポイントのひとつ
# 38  38              カフェ ゆとりの空間                  栗原晴美さんの店、ゆとりの空間
# 39  39                   穂多木神社                    旧拓銀の神社だったんですね
# 40  40               北海道立近代美術館                  たまには美術鑑賞をしてみようか
# 41  41              滝野すずらん丘陵公園                 広々とした園内には花がいっぱい！
# 42  42                   円山原始林                札幌の中心街に近いのにこの大自然！
# 43  43                 かんのファーム                     １０月初旬は花盛りでした
# 44  44         ジンギスカン ひげのうし 本店        ジンギスカンの肉って、こんなに種類があるんですね！
# 45  45               札幌ステラプレイス                 明るく開放的なショッピングゾーン
# 46  46                       旭岳               標高２２９１ｍは北海道最高峰です！
# 47  47                   三階滝公園                     マイナスイオンたっぷり！
# 48  48                  北大銀杏並木              日本じゃないみたいなイチョウ並木を歩く
# 49  49          東横INN 札幌すすきの交差点               すすきの交差点のすぐそばにあります
#
#                                           review_main  rank
# 0   　三笠市の市街から東へ進むと、建設中の新桂沢ダムがありました。今の桂沢ダムによって川がせき止...     3
# 1   　三笠市から富良野市へ向かう途中、まもなく富良野方面に右折するというあたりに、三段滝公園があ...     4
# 2   　札幌東急REIホテルは、札幌のすすきのにある大型のホテルです。以前、札幌東急インと呼ばれて...     4
# 3   　古くからある札幌を代表する商店街である狸小路。一時はちょっとさびれた感も感じられるような商...     4
# 4   　三笠市の市街地から東へ向かいました。道の両側に田んぼが続く平地が終わり、山間部へ入ったあた...     3
# 5   　美瑛近くで国道からそれて東へ向かい、忠別ダムを過ぎてからはずっと続くワインディングロードを...     5
# 6   　富良野方面から大雪山へ向かう途中、国道沿いにあるこちらに立ち寄りました。初夏や夏に何度か通...     4
# 7   　支笏湖と千歳の市街地を結んでいる道路で、支笏湖側からは、いったん上った後は、ゆるやかにずー...     4
# 8   　北湯沢温泉から千歳方面へ向かっている途中に立ち寄りました。場所は美笛峠のトンネルの西側の出...     4
# 9   　札幌の円山公園内にある北海道神宮。北海道の一宮にふさわしく、とても広い境内にはたくさんの木...     5
# 10  　ＪＲ札幌駅の東隣にあるビル、エスタの１０階に、札幌ラーメン共和国があります。ここには北海道...     4
# 11  　シュークリームがおいしいビアードパパ。ＪＲ札幌駅とつながっている札幌エスタの地下１階にある...     4
# 12  　札幌市の中心部から車で３０分あまり南の方に向かいました。真駒内のあたりの住宅街を過ぎると、...     4
# 13  　札幌ラーメンの有名店であるすみれのすすきの店に行ってきました。場所は、すすきの交差点のすぐ...     4
# 14  　千歳アウトレットモールレラでの買い物途中、昼食に利用しました。　レラの大きなフードコートの...     3
# 15  　富良野方面から旭川方面へ向かっている途中、上富良野町の市街地近くの国道横に駐車場がある、こ...     4
# 16  　ＪＲ札幌駅の駅ビルの東隣のビル、エスタ。その１０階に、札幌ラーメン共和国はあります。北海道...     4
# 17  　もう数年前になるんでしょうか。すすきのと西４丁目がつながってループ化されてから、初めて札幌...     3
# 18  　北海道神宮での参拝を終えた私たちは、木々が生い茂る広い境内を、東側へと続いている参道を歩き...     4
# 19  　旭岳ロープウェイ駅の手前にある無料駐車場の向かいに、旭岳ビジターセンターはありました。　ち...     3
# 20  　旭岳ロープウェイは、標高１１００ｍの山麓駅から１０分で１６００ｍの姿見駅へと私たちを運んで...     4
# 21  　三笠市の市街地から東へ向かい、道路沿いも田んぼが広がる平地から山道へと変わってしばらく走っ...     3
# 22  　札幌の中心部から西へ。地下鉄だとわずか１０分ほどで、こんなに緑が豊かな場所にたどり着くこと...     5
# 23  　三笠から富良野へ向かう途中に、立ち寄ってみた三段滝。あまり有名な滝ではないし、どんな滝なん...     4
# 24  　支笏湖畔にあるこちらの宿は、客室がわずか５部屋の隠れ家的なオーベルジュ風の宿です。私たちは...     5
# 25  　支笏湖ビジターセンターは、支笏湖の温泉街にあり、湖畔かせ少しだけ登ったところにありました。...     4
# 26  　ふじ屋NOODLEは、札幌すすきのにある新ラーメン横丁に入っているラーメン屋さんです。　い...     4
# 27  　牧歌の像は、ＪＲ札幌駅南口の広場にあるブロンズ像です。札幌市出身の彫刻家である本郷新氏の作...     3
# 28  　札幌駅前通は、ＪＲ札幌駅南口からすすきのまで、札幌の中心を南北に貫くメインストリートです。...     3
# 29  　札幌の地下鉄は、鉄のレールの上を鉄の車輪が接している電車ではありません。ゴムの車輪なんです...     4
# 30  　北海道神宮の境内の中、西側にある駐車場から境内に入ったところに、こちらの六花亭神宮茶屋店が...     5
# 31  　札幌の時計台は、札幌のど真ん中にあります。周りを高層ビルに囲まれているため、小さな２階建て...     5
# 32  　恵庭のジェラート屋さん、ジジに、２年ぶりくらいでお邪魔してきました。おとなりのピザの姉妹店...     4
# 33  　ＪＲ恵庭駅北口から少し歩いたところにある恵庭ふるさと公園。住宅街の中にある広い公園で、緑が...     3
# 34  　久々の円山動物園を楽しんできました。一番のお目当ては、「空飛ぶシロクマ」。新しくできたシロ...     4
# 35  　北海道みやげの超定番と言える「白い恋人」。大阪に行ったときに、空港の売店で「面白い恋人」と...     4
# 36  　ミア・アンジェラ大丸札幌店は、大丸８階のレストラン街にあるイタリアン・レストランです。　カ...     4
# 37  　広大な面積を誇る滝野すずらん丘陵公園。入り口からお花畑を眺めながら頂上まで登り、その後は、...     3
# 38  　栗原はるみさんプロデュースの店、ゆとりの空間のカフェです。札幌駅に直結している大丸の５階に...     4
# 39  　北海道神宮でのお参りを済ませ、東側に延びる参道を歩いていると、その参道脇に並んでいた末社の...     3
# 40  　せっかく札幌に来たことだし、円山方面まで向かう途中にちょっと立ち寄ってみようかと思い、近代...     4
# 41  　札幌の市街地から南へしばらく走ると、あたりはすっかり山の中になります。そんな場所に、滝野す...     5
# 42  　久しぶりの円山動物園を出た後、円山に登ってみました。円山は、標高２００ｍあまりの小さな山な...     4
# 43  　富良野から旭川方面へ向かう国道２３７号線。その上富良野町と美瑛町の境界あたりにある丘にある...     4
# 44  　すすきのに宿泊していた私たちは、一日目の夕食をこちらの「ひげのうし」でジンギスカンをいただ...     4
# 45  　ＪＲ札幌駅直結のショッピングモール、札幌ステラプレイス。札幌から離れた北海道の地方都市に住...     3
# 46  　北海道最高峰の旭岳。標高２２９１ｍの山ですが、北海道の真ん中に位置している大雪山連峰は、東...     5
# 47  　北湯沢にある温泉ホテルに宿泊していた私たちは、千歳方面に向けて走り始めました。少し走ったと...     5
# 48  　北海道大学の広い構内にあるこちらのイチョウ並木。立派なイチョウの並木が道をすっぽりと覆って...     5
# 49  　東横イン札幌すすきの交差点は、その名の通り、すすきの交差点に建つ東横インです。ですから、地...     4

# %%
import numpy as np

def vectorize_texts(texts):
    total_vec = np.zeros(100)

    tokenized_words = tokenize(texts)
    word_size = len(tokenized_words)
    #print('最初の単語サイズ:', word_size)
    for i in tokenized_words:
        try:
            total_vec += model.wv[i]
        except KeyError:
            #print('辞書に登録されていない単語が出現したため、スキップします。')
            word_size -= 1

    #print('最終的な単語サイズ:', word_size)
    avg_vec = total_vec / word_size
    #print('テキストの分かち書きされた単語に対しての平均ベクトル:', avg_vec)
    return avg_vec

# %%
from scipy.spatial.distance import cosine

#類似度を出力するために　1-(cos距離）=1-(1-u*v/(|u|*|v|)=u*v/(|u|*|v|)
#※ | |はL2 Norm
def calculate_cos_similarity(vec1, vec2):
    num_of_features = 100
    return 1 - cosine(vec1, vec2)

# %%
print('==========================================case1==============================================')
#case1のテスト
atmosphere_vec1 = model.wv['落ち着く']
past_trip_you_liked_vec1 = model.wv['伊勢神宮']
hobby_vec1 = model.wv['散策']

print('雰囲気ベクトル', atmosphere_vec1)
print('好きな旅行先ベクトル', past_trip_you_liked_vec1)
print('趣味ベクトル', hobby_vec1)
print("\n")
print('==========================================case2==============================================')
#case2のテスト
atmosphere_vec2 = model.wv['にぎわう']
past_trip_you_liked_vec2 = model.wv['中州']
hobby_vec2 = model.wv['グルメ']

print('雰囲気ベクトル', atmosphere_vec2)
print('好きな旅行先ベクトル', past_trip_you_liked_vec2)
print('趣味ベクトル', hobby_vec2)
# Out:
# ==========================================case1==============================================
# 雰囲気ベクトル [ 0.07862108 -0.1809221  -0.4911421   0.20355673 -0.12601174 -0.2708294
#  -0.37161562  0.35602322 -0.233707    0.5619182   0.00392822 -0.4777614
#   0.33409184  0.02171683  0.5134428   0.6008894  -0.23014769  0.01334549
#  -0.04008425 -0.08220636  0.5905624  -0.06472889 -0.07548473  0.23423518
#  -0.16916148 -0.42936364  0.14313643  0.15990955 -0.3952685   0.30590338
#   0.42414227  0.26278073  0.01417148  0.58316475 -0.43525916  0.10113464
#  -0.00228763  0.3858147  -0.09358875 -0.29813376 -0.27670228 -0.03200711
#  -0.3095717  -0.25578377 -0.10427351 -0.42657    -0.10303719 -0.24495593
#   0.04549182 -0.45043996  0.21834637  0.3253257   0.13266061 -0.37430656
#  -0.08026135 -0.01844334 -0.41878012  0.13009414 -0.38077265  0.14760697
#  -0.39643475  0.47091463  0.25252488 -0.4980924   0.15321118 -0.31621113
#  -0.22568683  0.14611383  0.49928355  0.37338558  0.24201033  0.14785375
#   0.01357586 -0.12380141 -0.21523997  0.50380504 -0.4969694  -0.04321574
#   0.20762025  0.0969862  -0.06888517 -0.06943854  0.42777276 -0.3113632
#  -0.24693352 -0.2550513  -0.47130093  0.06688399 -0.08963052  0.09763817
#  -0.15806799 -0.10446558 -0.17372978  0.06560835  0.0549552   0.44684103
#   0.00195087 -0.23335327 -0.57386047 -0.433011  ]
# 好きな旅行先ベクトル [-0.16279742 -0.01033744 -0.229552   -0.14692566 -0.7837001  -0.40974322
#   0.13864931  0.22721662  0.25893173 -0.31583166 -0.1338982  -0.3854942
#   0.3114989  -0.04351417  0.25514498 -0.09118217 -0.4111457   0.15625672
#   0.25382996 -0.2932571   0.64116514  0.3936148   0.83084565  0.2732658
#   0.04068258 -0.52104026  0.12458562  0.48543108  0.20323832  0.6752442
#  -0.5370761   0.08297183  0.21648772 -0.33949307  0.11929078  0.01629328
#   0.06966754  0.40056956  0.24740224 -0.27766415  0.14768425 -0.51383275
#   0.03063817 -0.58128977 -0.29219893 -0.5925927   0.5909019   0.03277237
#   0.59796596 -0.53132486 -0.015577    0.17819445  0.7669369  -0.09421564
#   0.26798674  0.3109945   0.39571667  0.6212501   0.17263457 -0.77956414
#   0.07172149 -0.29451808  0.04630491 -0.06356337  0.44557738 -0.27247182
#   0.07785988 -0.06280648  0.6417063   0.17935836  0.7738996   0.45082408
#   0.03826072  0.10495654  0.10921503  0.45726725  0.4254601  -0.18438154
#  -0.18641008 -0.63835746  0.55745065 -0.069911    0.19558814 -0.3440226
#   1.0859485   0.04811307 -0.11929192  0.10234495 -0.13982305 -0.39891088
#  -0.26724818  0.14182253  0.28315583 -0.3380719  -0.40776998 -0.21764566
#  -0.58759457  0.11914696 -0.01252232 -0.15220216]
# 趣味ベクトル [ 0.10189041  0.22837171 -1.1375698   0.45464915 -0.49639767 -0.3115271
#  -0.4993422   0.20082305  0.6999678  -0.30228797  0.13909563 -0.34253627
#   0.5616518   0.34585193 -0.43256268 -0.3011045  -0.6577189  -0.20124641
#   0.08805203 -0.35106143  0.20661135  0.14212398  0.04085856  0.06136671
#  -0.2998181  -0.558433   -0.16087696  0.12188938  0.1937365   0.56960064
#   0.10477012 -0.01124311  0.1461388   0.39286938 -0.535135   -0.27932295
#   0.3708038   0.58962435  0.4981869  -0.14171612 -0.5477358  -0.45664057
#  -0.09636465 -0.64012337 -0.12318037 -0.514237    0.12460126 -0.17201799
#   0.01901021  0.16690008 -0.74288553 -0.07123609  0.4244003  -0.09161638
#   0.75617987  0.41076663 -0.02749071  0.37737024  0.05871756  0.07365014
#   0.30250788  0.1778831  -0.06083955 -0.285528    0.6047396  -0.21347378
#   0.3384725   0.33463755  0.42613345  0.22489606  0.47082415  0.4481328
#   0.6138604   0.07084779 -0.42624962  0.24885093  0.23936217  0.22591558
#   0.37182218  0.15434223  0.0293599  -0.1635868   0.55246234 -0.05938507
#   0.40203598  0.5306753   0.5477035  -0.12653431 -0.8340176   0.27649954
#  -0.21229438 -0.2839141   0.06123709  0.01473238 -0.09699868  0.73538345
#   0.06622273 -0.07890831 -0.44928396 -0.05570786]
#
#
# ==========================================case2==============================================
# 雰囲気ベクトル [-0.24381973 -0.06757443 -0.8729795   0.16572675 -0.81065345 -0.39055696
#  -0.25615987  0.37857696  0.5515666  -0.0402487  -0.07863868 -0.45399016
#   0.44804838  0.2824468  -0.27338916 -0.10837371 -0.04304965 -0.12332289
#   0.36350894 -0.38495126  0.24314415  0.3256661   0.16023387  0.365226
#   0.67294776 -1.1708353   0.01175138 -0.04244587 -0.5368988   0.50989574
#   0.351891   -0.52560884  0.03694114  0.2776756  -0.4024566   0.8076971
#   0.54132926  0.69835734  0.6562273  -0.3772794  -0.16941692 -0.02961729
#  -0.5466185  -0.29274824 -0.4582089  -0.72640836  0.20813267  0.08318545
#  -0.13005136 -0.4256713  -0.30023575  0.25066507 -0.25638884 -0.17990819
#   0.53948116  0.6765207   0.19199729  0.1778395   0.20044322  0.512639
#   0.35445023 -0.04779062  0.3360841  -0.16390604  0.05312639 -0.28730968
#   0.3155361   0.54122573  0.00123249  0.41892645  0.5021485   0.05098868
#   0.29275683 -0.58852065 -0.6389646   0.33645868 -0.34436867  0.2921062
#  -0.55786324 -0.33488208  0.5056465   0.08434043 -0.10537878 -0.6098365
#   0.02583555 -0.03703637  0.10124785 -0.48523962 -1.0203958   0.01055735
#  -0.58277255  0.08495237  0.22857179 -0.03416064 -0.25336772  1.0941267
#  -0.22228831 -0.08902367 -0.34936705 -0.3321674 ]
# 好きな旅行先ベクトル [ 0.42859346  0.2451886  -0.7289089  -0.00982133 -0.09604818 -0.06804603
#  -0.31134102 -0.4270779   0.6534562   0.10328381  0.562021   -0.19032004
#   0.5198228   0.44650638  0.11351582  0.2002203  -0.26028135  0.17358392
#   0.47307426 -0.8352862  -0.07755316  0.2575287   0.45684466 -0.27943262
#  -0.16616434 -0.7966407  -0.5009667  -0.19612698  0.23521602  0.28326294
#  -0.16787356 -0.7417028   0.39235482 -0.26203012  0.02005696 -0.09488808
#  -0.51727885  0.74983305  0.00425414 -0.48618022  0.22157618 -0.10218173
#  -0.17858769 -0.37353107 -0.40760523 -0.2671278  -0.16168036  0.39582175
#  -0.29942942 -0.17785156 -0.0092574   0.12377279  0.23704271 -0.29218927
#   0.365177    0.1485239   0.03666937  0.09314206 -0.08961256 -0.05259082
#  -0.1492793   0.01445123 -0.45391008 -0.19413418 -0.16719815 -0.01156595
#  -0.32124105  0.20132978  0.01208663 -0.35453752  0.33681652  0.2389854
#   0.36749816 -0.05020504  0.35903424  0.36964598 -0.21955347 -0.26568326
#   0.24216807 -0.43370783  0.29290015 -0.3876321   0.48472857 -0.17047033
#  -0.1696819   0.2645505  -0.32118842  0.1919607  -0.6984867  -0.2912726
#  -0.04657298 -0.27568033  0.3659718  -0.17848994  0.11197066  0.23811379
#   0.35147402 -0.52536184 -0.37764096 -0.31077212]
# 趣味ベクトル [-0.53251547 -0.24501957 -0.534892   -0.43412715  0.00608227 -0.54406846
#  -0.12923254 -0.34091127 -0.41064712 -0.08810481 -0.11477229 -0.5239036
#   0.6197205   0.22952738 -0.45472565 -0.2752677  -0.72278494  0.22421849
#  -0.09267946  0.07825287  0.32735255 -0.04910048 -0.09133291  0.2720486
#   0.47872874  0.03729343  0.05994491 -0.19178466  0.32647663  0.08733671
#  -0.13140878 -0.0785934   0.08557384 -0.42803213 -0.22470681  0.28902334
#   0.20749357  0.10195071 -0.03670869  0.10042734 -0.22219628 -0.34462458
#   0.14113249 -0.2503965   0.12339881 -0.71451324  0.10478738  0.12680577
#   0.15065104 -0.388181    0.02072148 -0.25200155  0.8186466   0.3354388
#  -0.05700153  0.7021734  -0.52003783  0.09272724  0.27952343  0.3289256
#  -0.69133514  0.01037013 -0.17833951  0.26039672 -0.08363943  0.09961903
#   0.73265344  0.73323673  0.30901828 -0.19289863  0.37616527  0.78297246
#   0.54828906  0.91313463 -0.25568768 -0.2563683   0.1659417   0.18726796
#   0.10050119  0.07940113  0.3522583  -0.3607461   0.1966746  -0.30226412
#   0.32036367 -0.0862451   0.55319786 -0.21909468 -0.860031    0.55752003
#   0.27894592  0.0493409  -0.1598951  -0.3423778  -0.24684393  0.3726869
#   0.0210052  -0.8601645  -0.42141673 -0.2756379 ]

# %%
import pandas as pd
from statistics import mean

def calculate_cos_similarity_for_query(query1, query2, query3):
    
    atmosphere_vec = vectorize_texts(query1)
    past_trip_you_liked_vec = vectorize_texts(query2)
    hobby_vec = vectorize_texts(query3)
    
    csv_input = pd.read_csv("data/test_data.csv", sep=",")
    
    sim_list = []
    dict = {}
    
    for id, title, main in zip(csv_input['id'], csv_input['review_title'], csv_input['review_main']):
        
        title_vec = vectorize_texts(title)
        main_vec = vectorize_texts(main)
        
        tmp_list = [calculate_cos_similarity(atmosphere_vec, title_vec),\
                    calculate_cos_similarity(atmosphere_vec, main_vec),\
                    calculate_cos_similarity(past_trip_you_liked_vec, title_vec),\
                    calculate_cos_similarity(past_trip_you_liked_vec, main_vec),\
                    calculate_cos_similarity(hobby_vec, title_vec),\
                    calculate_cos_similarity(hobby_vec, main_vec)]
        
        feature_vec_avg = mean(tmp_list)
        #sim_list.append(id, feature_vec_avg)
        dict[id] = feature_vec_avg
        
    selected_idxes = []
    recommended_place_list = []

    for i, dic in enumerate(sorted(dict.items(), key=lambda x: -x[1])):
        selected_idxes.append(dic[0])
        if i == 9:
            break

    for i, idx in enumerate(selected_idxes):
        recommended_place_list.append((csv_input['rank'][idx], idx))

    sorted_list = sorted(recommended_place_list, reverse=True)
    print('sorted_list:', sorted_list)

    for i, tuple in enumerate(sorted_list):
        test = csv_input[csv_input['id']==tuple[1]]['place_name']
        print(test[tuple[1]])

# %%
calculate_cos_similarity_for_query('落ち着く', '伊勢神宮', '散策')
# Out:
# sorted_list: [(5, 41), (5, 30), (5, 22), (5, 9), (4, 40), (4, 25), (4, 23), (4, 18), (3, 39), (3, 37)]
#  滝野すずらん丘陵公園
#  六花亭 神宮茶屋店
#  円山公園
#  北海道神宮
#  北海道立近代美術館
#  支笏湖ビジターセンター
#  三段滝
#  開拓神社
#  穂多木神社
#  滝野すずらん丘陵公園 こどもの谷休憩所

# %%
calculate_cos_similarity_for_query('日本文化が感じれる場所', '鎌倉、清水寺、厳島神社、大仙陵古墳、太宰府天満宮、出雲大社', 'グルメ、観光')
# Out:
# sorted_list: [(5, 48), (5, 41), (5, 30), (5, 22), (5, 9), (4, 40), (4, 25), (4, 23), (4, 18), (3, 39)]
#  北大銀杏並木
#  滝野すずらん丘陵公園
#  六花亭 神宮茶屋店
#  円山公園
#  北海道神宮
#  北海道立近代美術館
#  支笏湖ビジターセンター
#  三段滝
#  開拓神社
#  穂多木神社

# %%
calculate_cos_similarity_for_query('夜景がきれいで、イチャイチャできる', 'みなとみらい、神戸ハーバーランド、函館', 'カラオケ、ショッピング')
# Out:
# sorted_list: [(5, 22), (4, 49), (4, 42), (4, 38), (4, 36), (4, 35), (4, 25), (4, 2), (3, 45), (3, 28)]
#  円山公園
# 東横INN 札幌すすきの交差点
#  円山原始林
#  カフェ ゆとりの空間
#  ミア アンジェラ 大丸札幌店
#  石屋製菓 大丸札幌店 ISHIYAショップ
#  支笏湖ビジターセンター
# 札幌東急REIホテル
#  札幌ステラプレイス
#  札幌駅前通
